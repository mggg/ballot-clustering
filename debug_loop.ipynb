# %%
from scot_helper_funcs import csv_parse
import os
import glob

# %%
filename_list = glob.glob("scot-elex/**/*.csv")

# %%
for filename in filename_list:
    print(filename)
    num_cands, election_dict, cand_list, ward = csv_parse(filename)
# Out:
# scot-elex\10_cands\aberdeenshire_2012_ward18.csv
# scot-elex\10_cands\aberdeenshire_2012_ward3.csv
# scot-elex\10_cands\aberdeenshire_2017_ward3.csv
# scot-elex\10_cands\aberdeenshire_2022_ward4.csv
# scot-elex\10_cands\aberdeen_2017_ward12.csv
# scot-elex\10_cands\aberdeen_2022_ward12.csv
# scot-elex\10_cands\aberdeen_2022_ward6.csv
# scot-elex\10_cands\angus_2022_ward6.csv
# scot-elex\10_cands\argyll_bute_2012_ward5.csv
# scot-elex\10_cands\argyll_bute_2017_ward5.csv
# scot-elex\10_cands\argyll_bute_2017_ward7.csv
# scot-elex\10_cands\dumgal_2017_ward9.csv
# scot-elex\10_cands\dundee_2017_ward2.csv
# scot-elex\10_cands\dundee_2017_ward4.csv
# scot-elex\10_cands\east_renfrewshire_2022_ward4.csv
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 for filename in filename_list:
#       2     print(filename)
# ...
